# %%
import pytesseract
from PIL import Image

pytesseract.pytesseract.tesseract_cmd = r"C:\Program Files\Tesseract-OCR\tesseract.exe"

img = Image.open("invoice.png")

text = pytesseract.image_to_string(img)

print(text)
# Out:
# Company Name IIAMWONGI
#
# [Street Address]
#
# [city, ST 2] pare [42/9/2019
# Phone: [000-000-0000] Invoice # (123456)
# Fax: [000-000-0000] ‘CUSTOMER ID 1123]
# ‘Website: somedomain.com Due pare [7478/2020
#
# [Name]
# {Company Name]
# [Street Address]
# [City, ST ZIP]
# [Phone]
#
# RIPTION
#
# [Service Fee] 730.00
# [Labor: § hours at $75/hr] 375.00
# [Parts] x 345.00
#
# 1, Total payment due in 30 days
# 2. Please include the invoice number on your check
#
# Make all checks payatie to
# [Your Company Name]
#
# If you have any questions about this invoice, please contact
# Name, Phone #, E-mail]
# Thank You For Your Business!
#
# ps: ww vertexe2.comfExcelTemplates excel invoice-tempate html Involoe Template © 2010-2019 by Vertext2.com

# %%
import cv2
import pytesseract
from PIL import Image

pytesseract.pytesseract.tesseract_cmd = r"C:\Program Files\Tesseract-OCR\tesseract.exe"

image = cv2.imread("invoice.png")

# Convert to grayscale
gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)

# Increase contrast
gray = cv2.convertScaleAbs(gray, alpha=1.5, beta=0)

# Threshold (makes text more clear)
_, thresh = cv2.threshold(gray, 150, 255, cv2.THRESH_BINARY)

# Save temporary
cv2.imwrite("processed.png", thresh)

# OCR
text = pytesseract.image_to_string("processed.png", config="--psm 6")

print(text)
# Out:
# Company Name
# [Screes Accress]
# (icy, 57 ZIP] CLE 12/9/2013
# Prone [986000-000] wwvcice = "Tease]
# Fae [990-000-2005] cusoren iS [123]
# [Nar]
# [Cor pany Nar s]
# [Screes Accress]
# (icy, 57 ZIP]
# [rons]
# DESCRIPTION TAXED AMOUNT
# [bators rau 2: $7567] 375.00
# [Pars] x 345.00
# aaa 3a
# “poste 3us.c0
# TOTAL $ 971.56
# [Your Company Name]
# Thank You For Your Business!

# %%
import pytesseract
from PIL import Image

pytesseract.pytesseract.tesseract_cmd = r"C:\Program Files\Tesseract-OCR\tesseract.exe"

img = Image.open("free-pic.jpg")

text = pytesseract.image_to_string(img)

print(text)
# Out:
# INVOICE
#
# Accounting
#
# a
#
# ° e000
# ooo°0
# o0o°0
#
# YOUR LOGO
#
# INVOICE _
# Invoice to:
# NAME SURENAME ;
# 1700 Biscayne Blvd, Miami, Invoice # 1234
# FL 33132, United Satates Date 10/10/2024
# No. Service Description Price Qty. Total
# 1 Lorem ipsum dolor sit $25.00 1 $25.00
# 2 Lorem ipsum dolor sit $25.00 1 $25.00
# 3 Lorem ipsum dolor sit $50.00 ] $50.00
# Terms and Conditions Subtotal $100.00
# Lorem ipsum dolor sit amet, consectetuer i i
# adipiscing elit, sed diam nonummy nibh Shipping $1 5.00
# euismod tincidunt ut laoreet dolore magna Tax Rate $1.00
#
# aliquam erat.
#
# TOTAL $116.00
#
# Questions:
#
# Email us: mail@yourcompany.com
# Call us: +12 345 6789 0
# Payment Info:
#
# Account #: 1234 5677 5432
#
# A/C Name: Lorem ipsum
#
# Bank Details: Add your bank detais
# Authorised Sign
#
# @Username @Username
